# %%
print("langgraph-tutorial-workbook-solutions.ipynb")
# Out:
# langgraph-tutorial-workbook-solutions.ipynb

# %% [markdown]
# # LangGraph Tutorial: From Motivation to LLM-Powered Agents
#
# This notebook introduces LangGraph, explains the problems it solves in LLM-powered applications, and walks through a runnable example using OpenAI, simple agents, and conditional routing.

# %% [markdown]
# ## 1. Introduction
#
# LangGraph is a framework for building **stateful, controllable, and reliable** LLM-powered applications using **graphs** rather than linear chains or free-form agent loops.
#
# Instead of letting an LLM implicitly decide what happens next, LangGraph makes:
# - Control flow **explicit**
# - State **shared and typed**
# - Execution **predictable and debuggable**
#
# This makes it suitable for real-world, production-grade AI systems.

# %% [markdown]
# ---
#
# ## 2. Problems with Earlier LLM-Powered Applications
#
# Before LangGraph, most LLM apps were built with:
# - Prompt-only calls
# - Linear chains
# - Autonomous agents
#
# These approaches work for prototypes but struggle in production.
#
# ### 2.1 Implicit Control Flow
# - Chains assume a fixed order
# - Agents decide the next step internally
# - Hard to enforce business rules or guardrails
#
# ### 2.2 Poor State Management
# - State hidden in prompts
# - Manual passing between steps
# - Easy to overwrite or lose context
#
# ### 2.3 Uncontrolled Agent Loops
# - Risk of infinite loops
# - Difficult to debug
# - Hard to reproduce failures
#
# ### 2.4 Low Observability
# - No clear execution trace
# - Hard to replay or inspect partial results
#
# ---
#
# ## 3. How LangGraph Solves These Problems
#
# LangGraph introduces:
# - Explicit graph-based orchestration
# - Typed shared state
# - Deterministic routing
# - Controlled loops and retries
#
# It applies classical software engineering principles—state machines, routing, orchestration—to LLM systems.
#
# ---
#
# ## 4. Modes of Using LangGraph
#
# ### 4.1 Single-Agent Graphs
# Structured workflows replacing complex chains.
#
# ### 4.2 Conditional and Tool-Oriented Graphs
# Decision-making systems with branching logic.
#
# ### 4.3 Multi-Agent Graphs
# Role-based agents coordinated via a supervisor or orchestrator.
#
# ---
#
# ## 5. Typical and Industry-Standard Workflow
#
# 1. Define typed state
# 2. Implement small, testable nodes
# 3. Define explicit routing
# 4. Compile the graph
# 5. Execute with observability and checkpoints
#
# This mirrors standard backend system design.
#
# ---
#
# ## 6. LLM-Powered Assistant with Agents and Conditional Routing
#
# ### Goal
#
# Build a simple assistant that:
# 1. Classifies user intent using an LLM
# 2. Routes execution based on that intent
# 3. Uses a specialized agent to respond
#
# ---

# %% [markdown]
# ### 6.1. Installation and Setup
#
# Make sure you have your OpenAI API key registered in your account.

# %%
# !pip install -q langgraph langchain langchain-openai

# %% [markdown]
# ### 6.2. Define the Shared State

# %%
from typing import TypedDict, Literal

# %%
class State(TypedDict):
    user_input: str
    intent: Literal["faq", "general", ""]
    response: str

# %% [markdown]
# ### 6.3. Initialize the LLM

# %%
from langchain_openai import ChatOpenAI

f = open(r"E:\Lenovo Ideapad 330\company-material\ai-upskill\key-vault\openai\ne-openai-api-key.txt")
apikey = f.read()
f.close()

llm = ChatOpenAI(
    model="gpt-4o-mini",   # or your Groq model
    api_key=apikey,
    temperature=0,
)

# %% [markdown]
# ## 6.4. Classifier Agent

# %%
def classify_intent(state: State) -> State:
    prompt = f"""
    Classify the user request into one category:
    - faq
    - general

    User request:
    {state['user_input']}

    Respond with one word.
    """

    intent = llm.invoke(prompt).content.strip().lower()

    return {
        **state,
        "intent": intent
    }

# %% [markdown]
# ## 6.5. FAQ Agent

# %%
def faq_agent(state: State) -> State:
    prompt = f"""
    You are a helpful FAQ assistant.
    Answer clearly and concisely:

    {state['user_input']}
    """

    response = llm.invoke(prompt).content

    return {
        **state,
        "response": response
    }

# %% [markdown]
# ### 6.6 General Chat Agent

# %%
def general_agent(state: State) -> State:
    prompt = f"""
    You are a general conversational assistant.

    User message:
    {state['user_input']}
    """

    response = llm.invoke(prompt).content

    return {
        **state,
        "response": response
    }

# %% [markdown]
# ### 6.7 Conditional Routing

# %%
def route_by_intent(state: State):
    if state["intent"] == "faq":
        return "faq"
    return "general"

# %% [markdown]
# ### 6.8 Build the LangGraph

# %%
from langgraph.graph import StateGraph, END

graph = StateGraph(State)

graph.add_node("classifier", classify_intent)
graph.add_node("faq", faq_agent)
graph.add_node("general", general_agent)

graph.set_entry_point("classifier")

graph.add_conditional_edges(
    "classifier",
    route_by_intent,
    {
        "faq": "faq",
        "general": "general"
    }
)

graph.add_edge("faq", END)
graph.add_edge("general", END)

app = graph.compile()

# %% [markdown]
# ## 6.9 Execute the Graph

# %%
result = app.invoke({
    "user_input": "How to prepare for a machine learning interview?",
    "intent": "",
    "response": ""
})

print("Intent:", result["intent"])
print("Response:", result["response"])
# Out:
# Intent: general
# Response: Preparing for a machine learning interview involves several key steps. Here’s a structured approach to help you get ready:
#
# ### 1. **Understand the Basics**
#    - **Fundamentals of Machine Learning**: Make sure you have a solid understanding of core concepts such as supervised vs. unsupervised learning, overfitting vs. underfitting, bias-variance tradeoff, and evaluation metrics (accuracy, precision, recall, F1 score, ROC-AUC).
#    - **Algorithms**: Familiarize yourself with common algorithms like linear regression, logistic regression, decision trees, random forests, support vector machines, k-nearest neighbors, and neural networks.
#
# ### 2. **Mathematics and Statistics**
#    - **Linear Algebra**: Understand vectors, matrices, and operations on them.
#    - **Calculus**: Be comfortable with derivatives and gradients, especially in the context of optimization.
#    - **Probability and Statistics**: Know concepts like distributions, Bayes' theorem, hypothesis testing, and statistical significance.
#
# ### 3. **Programming Skills**
#    - **Languages**: Be proficient in Python or R, as they are commonly used in machine learning.
#    - **Libraries**: Familiarize yourself with libraries such as NumPy, Pandas, Scikit-learn, TensorFlow, and PyTorch.
#
# ### 4. **Data Handling**
#    - **Data Preprocessing**: Understand techniques for cleaning and preparing data, including handling missing values, normalization, and feature engineering.
#    - **Exploratory Data Analysis (EDA)**: Be able to analyze datasets and extract insights using visualization tools (e.g., Matplotlib, Seaborn).
#
# ### 5. **Model Evaluation and Tuning**
#    - **Cross-Validation**: Know how to implement and interpret cross-validation techniques.
#    - **Hyperparameter Tuning**: Understand methods like grid search and random search for optimizing model performance.
#
# ### 6. **Deep Learning (if applicable)**
#    - **Neural Networks**: Understand the architecture of neural networks, activation functions, and backpropagation.
#    - **Frameworks**: Get hands-on experience with deep learning frameworks like TensorFlow or PyTorch.
#
# ### 7. **Projects and Practical Experience**
#    - **Portfolio**: Work on personal or open-source projects to showcase your skills. Include end-to-end projects that demonstrate your ability to handle data, build models, and derive insights.
#    - **Kaggle Competitions**: Participate in Kaggle competitions to gain practical experience and learn from the community.
#
# ### 8. **Behavioral Questions**
#    - Prepare for behavioral interview questions by reflecting on your past experiences, challenges faced, and how you approached problem-solving.
#
# ### 9. **Mock Interviews**
#    - Practice with mock interviews to get comfortable with the format and types of questions you might encounter. You can use platforms like Pramp or Interviewing.io.
#
# ### 10. **Stay Updated**
#    - Follow the latest trends and advancements in machine learning by reading research papers, blogs, and attending webinars or conferences.
#
# ### 11. **Prepare Questions**
#    - Have thoughtful questions ready to ask the interviewer about the company’s projects, team structure, and future directions in machine learning.
#
# By following these steps and dedicating time to each area, you’ll be well-prepared for your machine learning interview. Good luck!

# %% [markdown]
# ### 6.10 Key Takeaways
#
# - LLMs assist decision-making but do not control execution
# - Explicit graphs improve reliability and debuggability
# - LangGraph enables production-grade AI systems
