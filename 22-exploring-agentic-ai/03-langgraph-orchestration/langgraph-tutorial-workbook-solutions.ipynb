# %%
print("langgraph-tutorial-workbook-solutions.ipynb")
# Out:
# langgraph-tutorial-workbook-solutions.ipynb

# %% [markdown]
# # LangGraph Tutorial: From Motivation to LLM-Powered Agents
#
# This notebook introduces LangGraph, explains the problems it solves in LLM-powered applications, and walks through a runnable example using OpenAI, simple agents, and conditional routing.

# %% [markdown]
# ## 1. Introduction
#
# LangGraph is a framework for building **stateful, controllable, and reliable** LLM-powered applications using **graphs** rather than linear chains or free-form agent loops.
#
# Instead of letting an LLM implicitly decide what happens next, LangGraph makes:
# - Control flow **explicit**
# - State **shared and typed**
# - Execution **predictable and debuggable**
#
# This makes it suitable for real-world, production-grade AI systems.

# %% [markdown]
# ---
#
# ## 2. Problems with Earlier LLM-Powered Applications
#
# Before LangGraph, most LLM apps were built with:
# - Prompt-only calls
# - Linear chains
# - Autonomous agents
#
# These approaches work for prototypes but struggle in production.
#
# ### 2.1 Implicit Control Flow
# - Chains assume a fixed order
# - Agents decide the next step internally
# - Hard to enforce business rules or guardrails
#
# ### 2.2 Poor State Management
# - State hidden in prompts
# - Manual passing between steps
# - Easy to overwrite or lose context
#
# ### 2.3 Uncontrolled Agent Loops
# - Risk of infinite loops
# - Difficult to debug
# - Hard to reproduce failures
#
# ### 2.4 Low Observability
# - No clear execution trace
# - Hard to replay or inspect partial results
#
# ---
#
# ## 3. How LangGraph Solves These Problems
#
# LangGraph introduces:
# - Explicit graph-based orchestration
# - Typed shared state
# - Deterministic routing
# - Controlled loops and retries
#
# It applies classical software engineering principles—state machines, routing, orchestration—to LLM systems.
#
# ---
#
# ## 4. Modes of Using LangGraph
#
# ### 4.1 Single-Agent Graphs
# Structured workflows replacing complex chains.
#
# ### 4.2 Conditional and Tool-Oriented Graphs
# Decision-making systems with branching logic.
#
# ### 4.3 Multi-Agent Graphs
# Role-based agents coordinated via a supervisor or orchestrator.
#
# ---
#
# ## 5. Typical and Industry-Standard Workflow
#
# 1. Define typed state
# 2. Implement small, testable nodes
# 3. Define explicit routing
# 4. Compile the graph
# 5. Execute with observability and checkpoints
#
# This mirrors standard backend system design.
#
# ---
#
# ## 6. LLM-Powered Assistant with Agents and Conditional Routing
#
# ### Goal
#
# Build a simple assistant that:
# 1. Classifies user intent using an LLM
# 2. Routes execution based on that intent
# 3. Uses a specialized agent to respond
#
# ---

# %% [markdown]
# ### 6.1. Installation and Setup
#
# Make sure you have your OpenAI API key registered in your account.

# %%
# !pip install -q langgraph langchain langchain-openai

# %% [markdown]
# ### 6.2. Define the Shared State

# %%
from typing import TypedDict, Literal

# %%
class State(TypedDict):
    user_input: str
    intent: Literal["faq", "general", ""]
    response: str

# %% [markdown]
# ### 6.3. Initialize the LLM

# %%
from langchain_openai import OpenAI

f = open(r"E:\Lenovo Ideapad 330\company-material\ai-upskill\key-vault\openai\ne-openai-api-key.txt")
apikey = f.read()
f.close()

llm = OpenAI(model="gpt-3.5-turbo", temperature=0.9, openai_api_key=apikey)

# %% [markdown]
# ## 6.4. Classifier Agent

# %%
def classify_intent(state: State) -> State:
    prompt = f"""
    Classify the user request into one category:
    - faq
    - general

    User request:
    {state['user_input']}

    Respond with one word.
    """

    intent = llm.invoke(prompt).content.strip().lower()

    return {
        **state,
        "intent": intent
    }

# %% [markdown]
# ## 6.5. FAQ Agent

# %%
def faq_agent(state: State) -> State:
    prompt = f"""
    You are a helpful FAQ assistant.
    Answer clearly and concisely:

    {state['user_input']}
    """

    response = llm.invoke(prompt).content

    return {
        **state,
        "response": response
    }

# %% [markdown]
# ### 6.6 General Chat Agent

# %%
def general_agent(state: State) -> State:
    prompt = f"""
    You are a general conversational assistant.

    User message:
    {state['user_input']}
    """

    response = llm.invoke(prompt).content

    return {
        **state,
        "response": response
    }

# %% [markdown]
# ### 6.7 Conditional Routing

# %%
def route_by_intent(state: State):
    if state["intent"] == "faq":
        return "faq"
    return "general"

# %% [markdown]
# ### 6.8 Build the LangGraph

# %%
from langgraph.graph import StateGraph, END

graph = StateGraph(State)

graph.add_node("classifier", classify_intent)
graph.add_node("faq", faq_agent)
graph.add_node("general", general_agent)

graph.set_entry_point("classifier")

graph.add_conditional_edges(
    "classifier",
    route_by_intent,
    {
        "faq": "faq",
        "general": "general"
    }
)

graph.add_edge("faq", END)
graph.add_edge("general", END)

app = graph.compile()

# %% [markdown]
# ## 6.9 Execute the Graph

# %%
result = app.invoke({
    "user_input": "What is your refund policy?",
    "intent": "",
    "response": ""
})

print("Intent:", result["intent"])
print("Response:", result["response"])
# Out:
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 result = app.invoke({
#       2     "user_input": "What is your refund policy?",
#       3     "intent": "",
#       4     "response": ""
#
# File e:\Lenovo Ideapad 330\company-material\ai-upskill\ai\Lib\site-packages\langgraph\pregel\main.py:3309, in Pregel.invoke(self, input, config, context, stream_mode, print_mode, output_keys, interrupt_before, interrupt_after, durability, version, **kwargs)
#    3306             chunks.append(chunk)
#    3307 else:
#    3308     # v1: collect interrupts from updates stream
# -> 3309     for chunk in self.stream(
#    3310         input,
#    3311         config,
#    3312         context=context,
#    3313         stream_mode=(
#    3314             ["updates", "values"] if stream_mode == "values" else stream_mode
#    3315         ),
#    3316         print_mode=print_mode,
#    3317         output_keys=output_keys,
#    3318         interrupt_before=interrupt_before,
#    3319         interrupt_after=interrupt_after,
#    3320         durability=durability,
#    3321         **kwargs,
#    3322     ):
#    3323         if stream_mode == "values":
#    3324             if len(chunk) == 2:
#
# File e:\Lenovo Ideapad 330\company-material\ai-upskill\ai\Lib\site-packages\langgraph\pregel\main.py:2736, in Pregel.stream(self, input, config, context, stream_mode, print_mode, output_keys, interrupt_before, interrupt_after, durability, subgraphs, debug, version, **kwargs)
#    2734 for task in loop.match_cached_writes():
#    2735     loop.output_writes(task.id, task.writes, cached=True)
# -> 2736 for _ in runner.tick(
#    2737     [t for t in loop.tasks.values() if not t.writes],
#    2738     timeout=self.step_timeout,
#    2739     get_waiter=get_waiter,
#    2740     schedule_task=loop.accept_push,
#    2741 ):
#    2742     # emit output
#    2743     yield from _output(
#    2744         stream_mode,
#    2745         print_mode,
#    (...)   2751         _state_mapper,
#    2752     )
#    2753 loop.after_tick()
#
# File e:\Lenovo Ideapad 330\company-material\ai-upskill\ai\Lib\site-packages\langgraph\pregel\_runner.py:167, in PregelRunner.tick(self, tasks, reraise, timeout, retry_policy, get_waiter, schedule_task)
#     165 t = tasks[0]
#     166 try:
# --> 167     run_with_retry(
#     168         t,
#     169         retry_policy,
#     170         configurable={
#     171             CONFIG_KEY_CALL: partial(
#     172                 _call,
#     173                 weakref.ref(t),
#     174                 retry_policy=retry_policy,
#     175                 futures=weakref.ref(futures),
#     176                 schedule_task=schedule_task,
#     177                 submit=self.submit,
#     178             ),
#     179         },
#     180     )
#     181     self.commit(t, None)
#     182 except Exception as exc:
#
# File e:\Lenovo Ideapad 330\company-material\ai-upskill\ai\Lib\site-packages\langgraph\pregel\_retry.py:126, in run_with_retry(task, retry_policy, configurable)
#     124     task.writes.clear()
#     125     # run the task
# --> 126     return task.proc.invoke(task.input, config)
#     127 except ParentCommand as exc:
#     128     ns: str = config[CONF][CONFIG_KEY_CHECKPOINT_NS]
#
# File e:\Lenovo Ideapad 330\company-material\ai-upskill\ai\Lib\site-packages\langgraph\_internal\_runnable.py:656, in RunnableSeq.invoke(self, input, config, **kwargs)
#     654     # run in context
#     655     with set_config_context(config, run) as context:
# --> 656         input = context.run(step.invoke, input, config, **kwargs)
#     657 else:
#     658     input = step.invoke(input, config)
#
# File e:\Lenovo Ideapad 330\company-material\ai-upskill\ai\Lib\site-packages\langgraph\_internal\_runnable.py:400, in RunnableCallable.invoke(self, input, config, **kwargs)
#     398         run_manager.on_chain_end(ret)
#     399 else:
# --> 400     ret = self.func(*args, **kwargs)
#     401 if self.recurse and isinstance(ret, Runnable):
#     402     return ret.invoke(input, config)
#
# Cell In[5], line 13, in classify_intent(state)
#       9
#      10     Respond with one word.
#      11     """
#      12
# ---> 13     intent = llm.invoke(prompt).content.strip().lower()
#      14
#      15     return {
#      16         **state,
#
# File e:\Lenovo Ideapad 330\company-material\ai-upskill\ai\Lib\site-packages\langchain_core\language_models\llms.py:380, in BaseLLM.invoke(self, input, config, stop, **kwargs)
#     369 @override
#     370 def invoke(
#     371     self,
#    (...)    376     **kwargs: Any,
#     377 ) -> str:
#     378     config = ensure_config(config)
#     379     return (
# --> 380         self.generate_prompt(
#     381             [self._convert_input(input)],
#     382             stop=stop,
#     383             callbacks=config.get("callbacks"),
#     384             tags=config.get("tags"),
#     385             metadata=config.get("metadata"),
#     386             run_name=config.get("run_name"),
#     387             run_id=config.pop("run_id", None),
#     388             **kwargs,
#     389         )
#     390         .generations[0][0]
#     391         .text
#     392     )
#
# File e:\Lenovo Ideapad 330\company-material\ai-upskill\ai\Lib\site-packages\langchain_core\language_models\llms.py:791, in BaseLLM.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#     782 @override
#     783 def generate_prompt(
#     784     self,
#    (...)    788     **kwargs: Any,
#     789 ) -> LLMResult:
#     790     prompt_strings = [p.to_string() for p in prompts]
# --> 791     return self.generate(prompt_strings, stop=stop, callbacks=callbacks, **kwargs)
#
# File e:\Lenovo Ideapad 330\company-material\ai-upskill\ai\Lib\site-packages\langchain_core\language_models\llms.py:1013, in BaseLLM.generate(self, prompts, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     994 if (self.cache is None and get_llm_cache() is None) or self.cache is False:
#     995     run_managers = [
#     996         callback_manager.on_llm_start(
#     997             self._serialized,
#    (...)   1011         )
#    1012     ]
# -> 1013     return self._generate_helper(
#    1014         prompts,
#    1015         stop,
#    1016         run_managers,
#    1017         new_arg_supported=bool(new_arg_supported),
#    1018         **kwargs,
#    1019     )
#    1020 if len(missing_prompts) > 0:
#    1021     run_managers = [
#    1022         callback_managers[idx].on_llm_start(
#    1023             self._serialized,
#    (...)   1030         for idx in missing_prompt_idxs
#    1031     ]
#
# File e:\Lenovo Ideapad 330\company-material\ai-upskill\ai\Lib\site-packages\langchain_core\language_models\llms.py:817, in BaseLLM._generate_helper(self, prompts, stop, run_managers, new_arg_supported, **kwargs)
#     806 def _generate_helper(
#     807     self,
#     808     prompts: list[str],
#    (...)    813     **kwargs: Any,
#     814 ) -> LLMResult:
#     815     try:
#     816         output = (
# --> 817             self._generate(
#     818                 prompts,
#     819                 stop=stop,
#     820                 # TODO: support multiple run managers
#     821                 run_manager=run_managers[0] if run_managers else None,
#     822                 **kwargs,
#     823             )
#     824             if new_arg_supported
#     825             else self._generate(prompts, stop=stop)
#     826         )
#     827     except BaseException as e:
#     828         for run_manager in run_managers:
#
# File e:\Lenovo Ideapad 330\company-material\ai-upskill\ai\Lib\site-packages\langchain_openai\llms\base.py:492, in BaseOpenAI._generate(self, prompts, stop, run_manager, **kwargs)
#     476     choices.append(
#     477         {
#     478             "text": generation.text,
#    (...)    489         }
#     490     )
#     491 else:
# --> 492     response = self.client.create(prompt=_prompts, **params)
#     493     if not isinstance(response, dict):
#     494         # V1 client returns the response in an PyDantic object instead of
#     495         # dict. For the transition period, we deep convert it to dict.
#     496         response = response.model_dump()
#
# File e:\Lenovo Ideapad 330\company-material\ai-upskill\ai\Lib\site-packages\openai\_utils\_utils.py:286, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     284             msg = f"Missing required argument: {quote(missing[0])}"
#     285     raise TypeError(msg)
# --> 286 return func(*args, **kwargs)
#
# File e:\Lenovo Ideapad 330\company-material\ai-upskill\ai\Lib\site-packages\openai\resources\completions.py:550, in Completions.create(self, model, prompt, best_of, echo, frequency_penalty, logit_bias, logprobs, max_tokens, n, presence_penalty, seed, stop, stream, stream_options, suffix, temperature, top_p, user, extra_headers, extra_query, extra_body, timeout)
#     521 @required_args(["model", "prompt"], ["model", "prompt", "stream"])
#     522 def create(
#     523     self,
#    (...)    548     timeout: float | httpx.Timeout | None | NotGiven = not_given,
#     549 ) -> Completion | Stream[Completion]:
# --> 550     return self._post(
#     551         "/completions",
#     552         body=maybe_transform(
#     553             {
#     554                 "model": model,
#     555                 "prompt": prompt,
#     556                 "best_of": best_of,
#     557                 "echo": echo,
#     558                 "frequency_penalty": frequency_penalty,
#     559                 "logit_bias": logit_bias,
#     560                 "logprobs": logprobs,
#     561                 "max_tokens": max_tokens,
#     562                 "n": n,
#     563                 "presence_penalty": presence_penalty,
#     564                 "seed": seed,
#     565                 "stop": stop,
#     566                 "stream": stream,
#     567                 "stream_options": stream_options,
#     568                 "suffix": suffix,
#     569                 "temperature": temperature,
#     570                 "top_p": top_p,
#     571                 "user": user,
#     572             },
#     573             completion_create_params.CompletionCreateParamsStreaming
#     574             if stream
#     575             else completion_create_params.CompletionCreateParamsNonStreaming,
#     576         ),
#     577         options=make_request_options(
#     578             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     579         ),
#     580         cast_to=Completion,
#     581         stream=stream or False,
#     582         stream_cls=Stream[Completion],
#     583     )
#
# File e:\Lenovo Ideapad 330\company-material\ai-upskill\ai\Lib\site-packages\openai\_base_client.py:1297, in SyncAPIClient.post(self, path, cast_to, body, content, options, files, stream, stream_cls)
#    1288     warnings.warn(
#    1289         "Passing raw bytes as `body` is deprecated and will be removed in a future version. "
#    1290         "Please pass raw bytes via the `content` parameter instead.",
#    1291         DeprecationWarning,
#    1292         stacklevel=2,
#    1293     )
#    1294 opts = FinalRequestOptions.construct(
#    1295     method="post", url=path, json_data=body, content=content, files=to_httpx_files(files), **options
#    1296 )
# -> 1297 return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File e:\Lenovo Ideapad 330\company-material\ai-upskill\ai\Lib\site-packages\openai\_base_client.py:1070, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1067             err.response.read()
#    1069         log.debug("Re-raising status error")
# -> 1070         raise self._make_status_error_from_response(err.response) from None
#    1072     break
#    1074 assert response is not None, "could not resolve response (should never happen)"
#
# NotFoundError: Error code: 404 - {'error': {'message': 'This is a chat model and not supported in the v1/completions endpoint. Did you mean to use v1/chat/completions?', 'type': 'invalid_request_error', 'param': 'model', 'code': None}}
# During task with name 'classifier' and id '35bb9ed3-5c14-f2c9-b4ec-29a012d66b96'

# %% [markdown]
# ### 6.10 Key Takeaways
#
# - LLMs assist decision-making but do not control execution
# - Explicit graphs improve reliability and debuggability
# - LangGraph enables production-grade AI systems
